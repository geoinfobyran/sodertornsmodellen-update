# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
from helpers import (readMaster, baskod2010tobasomrade, byGender, appendNewDatapoints, plotcombined)

# %% [markdown]
# Read data

# %%
master = readMaster()

# %%
df = master[['year', 'BASKODER', 'Befolkning män 16-', 'Befolkning kvinnor 16-', 'Befolkning tot 16-']]

# %%
df = df.rename(columns={
    'BASKODER': 'BASKOD2010',
    'Befolkning män 16-': 'pop_gte_16_male',
    'Befolkning kvinnor 16-': 'pop_gte_16_female',
    'Befolkning tot 16-': 'pop_gte_16'
})

# %%
df = baskod2010tobasomrade(df, n_numeric=3)

# %%
df['year'] = pd.to_datetime(df['year'])

# %%
df['year'] = df['year'].apply(lambda t: t.year)

# %% [markdown]
# Export

# %%
concept = 'population_gte_16'

# %%
out = df[['basomrade', 'year', 'pop_gte_16']].copy().rename(columns={'pop_gte_16': 'value'})
out = appendNewDatapoints(concept, out, new=True)
plotcombined(out)

# %%
concept = 'population_gte_16_male'

# %%
out = df[['basomrade', 'year', 'pop_gte_16_male']].copy().rename(columns={'pop_gte_16_male': 'value'})
out = appendNewDatapoints(concept, out, new=True)
plotcombined(out)

# %%
concept = 'population_gte_16_female'

# %%
out = df[['basomrade', 'year', 'pop_gte_16_female']].copy().rename(columns={'pop_gte_16_female': 'value'})
out = appendNewDatapoints(concept, out, new=True)
plotcombined(out)
