# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
from helpers import (readMaster, baskod2010tobasomrade, byGender, appendNewDatapoints, plotcombined)

# %% [markdown]
# Read data

# %%
master = readMaster()

# %%
df = master[['year', 'BASKODER', 'Befolkning män18-64', 'Befolkning kvinnor 18-64', 'Befolkning totalt 18-64']]

# %%
df = df.rename(columns={
    'BASKODER': 'BASKOD2010',
    'Befolkning män18-64': 'pop_male_18_64',
    'Befolkning kvinnor 18-64': 'pop_female_18_64',
    'Befolkning totalt 18-64': 'pop_tot_18_64'
})

# %%
df = baskod2010tobasomrade(df, n_numeric=3)

# %%
df['year'] = pd.to_datetime(df['year'])

# %%
df['year'] = df['year'].apply(lambda t: t.year)

# %% [markdown]
# Export

# %%
concept = 'population_aged_18_64'

# %%
out = df[['basomrade', 'year', 'pop_tot_18_64']].copy().rename(columns={'pop_tot_18_64': 'value'})
out = appendNewDatapoints(concept, out, new=True)
plotcombined(out)

# %%
concept = 'population_aged_18_64_male'

# %%
out = df[['basomrade', 'year', 'pop_male_18_64']].copy().rename(columns={'pop_male_18_64': 'value'})
out = appendNewDatapoints(concept, out, new=True)
plotcombined(out)

# %%
concept = 'population_aged_18_64_female'

# %%
out = df[['basomrade', 'year', 'pop_female_18_64']].copy().rename(columns={'pop_female_18_64': 'value'})
out = appendNewDatapoints(concept, out, new=True)
plotcombined(out)
